# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#functionsal
plt.plot(x,y)

# %%
#functionsal
plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
plt.subplot(1,2,1)
plt.plot(x,y, 'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')
